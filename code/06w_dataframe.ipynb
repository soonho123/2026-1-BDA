# %% [markdown]
# <a href="https://colab.research.google.com/github/ai7dnn/2026-1-BDA/blob/main/code/06w_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

pf = pd.DataFrame(data = [[25, 35, 8, 18],
                          [18, 27, 10, 20],
                          [17, 17, 10, 19],
                          [12, 22, 9, 20],
                          [22, 34, 8, 16]],
                  index=['윤일형', '강수희', '홍소희', '유한빈', '신수빈'],
                  columns=['중간', '기말', '과제', '출석'])
pf
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20
# 신수빈  22  34   8  16

# %%
pf['과제']
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# 유한빈     9
# 신수빈     8
# Name: 과제, dtype: int64

# %%
pf.과제
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# 유한빈     9
# 신수빈     8
# Name: 과제, dtype: int64

# %%
pf[ ['과제'] ]
# Out:
#      과제
# 윤일형   8
# 강수희  10
# 홍소희  10
# 유한빈   9
# 신수빈   8

# %%
pf.과제
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# 유한빈     9
# 신수빈     8
# Name: 과제, dtype: int64

# %%
pf[ ['과제', '기말'] ]
# Out:
#      과제  기말
# 윤일형   8  35
# 강수희  10  27
# 홍소희  10  17
# 유한빈   9  22
# 신수빈   8  34

# %%
import pandas as pd

df = pd.read_csv('2016년졸음운전.csv',
                 encoding='euc-kr', index_col=0)
df
# Out:
#           사고(건)  사망(명)  부상(명)
# 연월
# 2016년1월     192      5    387
# 2016년2월     174      6    328
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년5월     239     13    522
# 2016년6월     200     12    362
# 2016년7월     227      9    460
# 2016년8월     230      7    490
# 2016년9월     187     13    347
# 2016년10월    183     10    367
# 2016년11월    200      5    418
# 2016년12월    168      4    364

# %%
df.dtypes
# Out:
# 사고(건)    int64
# 사망(명)    int64
# 부상(명)    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2016년1월 to 2016년12월
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사고(건)   12 non-null     int64
#  1   사망(명)   12 non-null     int64
#  2   부상(명)   12 non-null     int64
# dtypes: int64(3)
# memory usage: 384.0+ bytes

# %%
df.describe()
# Out:
#             사고(건)      사망(명)       부상(명)
# count   12.000000  12.000000   12.000000
# mean   202.750000   8.166667  408.250000
# std     23.014324   3.186144   60.051682
# min    168.000000   4.000000  328.000000
# 25%    186.000000   5.750000  363.500000
# 50%    200.000000   7.000000  402.500000
# 75%    219.500000  10.500000  441.250000
# max    239.000000  13.000000  522.000000
